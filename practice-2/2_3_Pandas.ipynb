# %% [markdown]
# <a href="https://colab.research.google.com/github/AnastasiaKovalenko232/iad-practices/blob/main/practice-2/2_3_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Pandas

# %%
# https://pandas.pydata.org/docs/getting_started/index.html#getting-started

# %%
import numpy as np
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
columns = ['A', 'B', 'C', 'D'] # titles
columns
# Out:
# ['A', 'B', 'C', 'D']

# %%
data = np.array([[1, 2, -1, 0], [3, -1, 2, 5], [-1, 4, 0, 2], [-1, -2, 3, 0]])
data
# Out:
# array([[ 1,  2, -1,  0],
#        [ 3, -1,  2,  5],
#        [-1,  4,  0,  2],
#        [-1, -2,  3,  0]])

# %%
# create a data frame
df = pd.DataFrame(data=data, columns=columns)

# %%
df
# Out:
#    A  B  C  D
# 0  1  2 -1  0
# 1  3 -1  2  5
# 2 -1  4  0  2
# 3 -1 -2  3  0

# %%
# accessing a column
df['A']
# Out:
# 0    1
# 1    3
# 2   -1
# 3   -1
# Name: A, dtype: int64

# %%
# accessing many columns
df[['A', 'C']]
# Out:
#    A  C
# 0  1 -1
# 1  3  2
# 2 -1  0
# 3 -1  3

# %%
# chained access
df[['A', 'C']]['A']
# Out:
# 0    1
# 1    3
# 2   -1
# 3   -1
# Name: A, dtype: int64

# %%
# new column
df['E'] = df['A'] + df['B']
df
# Out:
#    A  B  C  D  E
# 0  1  2 -1  0  3
# 1  3 -1  2  5  2
# 2 -1  4  0  2  3
# 3 -1 -2  3  0 -3

# %%
# filtering data accoring to predicate
df[df > 0]
# Out:
#      A    B    C    D    E
# 0  1.0  2.0  NaN  NaN  3.0
# 1  3.0  NaN  2.0  5.0  2.0
# 2  NaN  4.0  NaN  2.0  3.0
# 3  NaN  NaN  3.0  NaN  NaN

# %%
# filtering data accoring to predicate
# and chaining column selection
df[ df > 2 ]['E']
# Out:
# 0    3.0
# 1    NaN
# 2    3.0
# 3    NaN
# Name: E, dtype: float64
