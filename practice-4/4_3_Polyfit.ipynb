# %% [markdown]
# <a href="https://colab.research.google.com/github/AnastasiaKovalenko232/iad-practices/blob/main/practice-4/4_3_Polyfit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.linear_model import SGDRegressor
from sklearn.pipeline import make_pipeline

# %%
# data
N = 100
x = np.linspace(-2, 2, N)
noise = np.random.normal(0, .5, N)
y0 = x**4 - 3*x**2 + x + 5
y = y0 + noise

# %%
# polyfit
coef = np.polyfit(x, y, deg=4)
y_fit = np.polyval(coef, x)
coef # c4, c3, c2, c1, c0
# Out:
# array([ 1.00621608,  0.0465815 , -2.97736121,  0.85898554,  4.9728213 ])

# %%
# display
plt.grid()
plt.plot(x, y0, "b", label="Original function")
plt.scatter(x, y, color="g", marker =".", label="Original + noise (data)", alpha=0.6)
plt.plot(x, y_fit, label="polyfit", color="r")
plt.legend()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1. Ті самі дані полінома 4-го ступеня
N = 100
x = np.linspace(-2, 2, N)
noise = np.random.normal(0, 0.5, N)
y0 = x**4 - 3*x**2 + x + 5
y = y0 + noise

# 2. Використання швидкого np.polyfit (deg=4 означає поліном 4-го ступеня)
# Функція повертає масив коефіцієнтів [c4, c3, c2, c1, c0]
coef = np.polyfit(x, y, deg=4)

# 3. Обчислення значень Y на основі знайдених коефіцієнтів
y_fit = np.polyval(coef, x)

print("Знайдені коефіцієнти NumPy polyfit (від старшого до молодшого):")
for i, c in enumerate(coef):
    print(f"c_{4-i} = {c:.4f}")

# 4. Графік
plt.figure(figsize=(8, 5))
plt.grid(True, linestyle='--', alpha=0.5)
plt.scatter(x, y, marker='.', color='orange', label='Точки даних')
plt.plot(x, y_fit, color='black', linewidth=2, label='Лінія np.polyfit')
plt.title('Апроксимація за допомогою np.polyfit')
plt.legend()
plt.show()
# Out:
# Знайдені коефіцієнти NumPy polyfit (від старшого до молодшого):
# c_4 = 1.0534
# c_3 = -0.0581
# c_2 = -3.1957
# c_1 = 1.2079
# c_0 = 5.1072
