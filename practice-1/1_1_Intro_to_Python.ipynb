# %% [markdown]
# <a href="https://colab.research.google.com/github/AnastasiaKovalenko232/iad-practices/blob/main/1_1_Intro_to_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Basics of Python: Data Types
# Python is an interpreted high-level general-purpose programming language. Its design philosophy emphasizes code readability with its use of significant indentation. Python is dynamically-typed and garbage-collected. It supports multiple programming paradigms, including object-oriented and functional programming (https://en.wikipedia.org/wiki/Python).
#
# (this is not a overview of Python in general, this notebook is just about some elementary concepts)
# ### Numbers

# %%
a = 1 # variables created when assigned
b = 2
print(a + b)
print(a * b)
print(a ** b - a / b)
# Out:
# 3
# 2
# 0.5

# %% [markdown]
# ### Lists
# Lists are useed to store multiple items in a single variable.

# %%
a = [1, 2, 3]
a
# Out:
# [1, 2, 3]

# %%
a.append('Hello!')

# %%
a
# Out:
# [1, 2, 3, 'Hello!']

# %%
for i in range(len(a)): # range(len(a)) creates a sequence of numbers from 0 to len(a)
    print(i, a[i])
# Out:
# 0 1
# 1 2
# 2 3
# 3 Hello!

# %%
print(type(a[0]))
print(type(a[-1])) # last element
# Out:
# <class 'int'>
# <class 'str'>

# %%
a[1:]
# Out:
# [2, 3, 'Hello!']

# %%
a[:-2]
# Out:
# [1, 2]

# %%
a[0] = ['u', 0, 3]
print(a)
print(a[0][0])
# Out:
# [['u', 0, 3], 2, 3, 'Hello!']
# u

# %%
new_list = [i**2 for i in range(5)] # list comprehensions

# %%
new_list
# Out:
# [0, 1, 4, 9, 16]

# %%
a1 = [1, 2, 3]
a2 = ['1', '2', '3']

# %%
a1 + a2 # concatenation
# Out:
# [1, 2, 3, '1', '2', '3']

# %%
matrix = [[1, 2, 3], [4, 5, 6]]

# %%
matrix
# Out:
# [[1, 2, 3], [4, 5, 6]]

# %%
len(matrix)
# Out:
# 2

# %%
len(matrix[0])
# Out:
# 3

# %% [markdown]
# ### Dictionaries
# Dictionary are used to store data values in key:value pairs.

# %%
d = {'key_1': 'value_1', 'key_2': 'value_2'}
print(d)
# Out:
# {'key_1': 'value_1', 'key_2': 'value_2'}

# %%
d['key_1']
# Out:
# 'value_1'

# %%
d.keys()
# Out:
# dict_keys(['key_1', 'key_2'])

# %% [markdown]
# ## Basics of Python: Functions
# a function is defined using the def keyword.

# %%
def hello_function():
    print("Hello!")

# %%
def my_function(x, y):
    return x**3, x + y

# %%
hello_function()
# Out:
# Hello!

# %%
my_function(4, 1)
# Out:
# (64, 5)
